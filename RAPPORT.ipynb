# %%
print("Bonjour INF1102")
# Out:
# Bonjour INF1102

# %%
a = 5
b = 7
print(a + b)
# Out:
# 12

# %%
nom = "Mohand"
print("Bonjour", nom)
# Out:
# Bonjour Mohand

# %%
age = 25

if age >= 18:
    print("Tu es majeur")
else:
    print("Tu es mineur")
# Out:
# Tu es majeur

# %%
for i in range(5):
    print("Numéro :", i)
# Out:
# Numéro : 0
# Numéro : 1
# Numéro : 2
# Numéro : 3
# Numéro : 4
